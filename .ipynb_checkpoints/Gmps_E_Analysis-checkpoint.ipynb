# %% [markdown]
# # Análisis Cualitativo

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('df_sup.csv')

# %% [markdown]
# ## Brief description of columns:
# 'id': Individual identifier of each register.
# 'title': Name of local commercial.
# 'id_sec': Individual idenfier of principal sector. (10)
# 'id_subsec': Individual identifier of subsector.  (\~130)
# 'cod_sec': Principal sector code. (10)
# 'cod_sub': Sub sector code. (\~130)
# 'sector': Sub sector description.
# 'lon' and 'lat': longitude and latittude information
# 'geometry': Location format information.
# 'polygon': Polygon´s name.
# 'franchise': If match with retail chains list.(1 -> true, 0 -> false).
# 'in_poly': Categorical feature, 0 out and 1 inside of the polygon.

# %%
df['franchise'].unique()
# Out:
# array([0., 1.])

# %%
col = df.columns.tolist()
for column in col:
  print("{}: {}".format(column, df[column].isnull().sum()))
# Out:
# id: 0
# title: 0
# id_sec: 0
# id_subsec: 0
# cod_sec: 0
# cod_sub: 0
# sector: 0
# lon: 0
# lat: 0
# geometry: 0
# polygon: 0
# franchise: 0
# in_hex: 0
# in_poly: 0

# %%
df.head()
# Out:
#          id             title  id_sec  id_subsec cod_sec cod_sub  \
# 0   83969.0     Garces Taller     9.0       12.0    tran    tall
# 1  117499.0        Anton Solé     9.0       12.0    tran    tall
# 2  117503.0  Auto.Carburación     9.0       12.0    tran    tall
# 3  117511.0      M.F, Flomart     9.0       12.0    tran    tall
# 4  117515.0         F.Espunes     9.0       12.0    tran    tall
#
#             sector       lon        lat                         geometry  \
# 0  taller mecánico  2.153513  41.379259  POINT (2.153512887 41.37925891)
# 1  taller mecánico  2.158677  41.373892  POINT (2.158676542 41.37389224)
# 2  taller mecánico  2.159230  41.374581  POINT (2.159229711 41.37458085)
# 3  taller mecánico  2.171383  41.372399  POINT (2.171382973 41.37239903)
# 4  taller mecánico  2.167696  41.371787  POINT (2.167695814 41.37178696)
#
#   polygon  franchise  in_hex  in_poly
# 0     out        0.0  1097.0        0
# 1     out        0.0  1158.0        0
# 2     out        0.0  1158.0        0
# 3     out        0.0  1185.0        0
# 4     out        0.0  1183.0        0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore') # Para evitar los molestos avisos.
# %matplotlib inline

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
corr = df.corr()
corr[['in_poly']].sort_values(by = 'in_poly',ascending = False)\
.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_39d6519e_7906_11ea_9646_90324b2c20c6row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_39d6519e_7906_11ea_9646_90324b2c20c6row1_col0 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_39d6519e_7906_11ea_9646_90324b2c20c6row2_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_39d6519e_7906_11ea_9646_90324b2c20c6row3_col0 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_39d6519e_7906_11ea_9646_90324b2c20c6row4_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_39d6519e_7906_11ea_9646_90324b2c20c6row5_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_39d6519e_7906_11ea_9646_90324b2c20c6row6_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_39d6519e_7906_11ea_9646_90324b2c20c6row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_39d6519e_7906_11ea_9646_90324b2c20c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >in_poly</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_39d6519e_7906_11ea_9646_90324b2c20c6level0_row0" class="row_heading level0 row0" >in_poly</th>
#                         <td id="T_39d6519e_7906_11ea_9646_90324b2c20c6row0_col0" class="data row0 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_39d6519e_7906_11ea_9646_90324b2c20c6level0_row1" class="row_heading level0 row1" >franchise</th>
#                         <td id="T_39d6519e_7906_11ea_9646_90324b2c20c6row1_col0" class="data row1 col0" >0.072948</td>
#             </tr>
#             <tr>
#                         <th id="T_39d6519e_7906_11ea_9646_90324b2c20c6level0_row2" class="row_heading level0 row2" >id</th>
#                         <td id="T_39d6519e_7906_11ea_9646_90324b2c20c6row2_col0" class="data row2 col0" >0.0401995</td>
#             </tr>
#             <tr>
#                         <th id="T_39d6519e_7906_11ea_9646_90324b2c20c6level0_row3" class="row_heading level0 row3" >in_hex</th>
#                         <td id="T_39d6519e_7906_11ea_9646_90324b2c20c6row3_col0" class="data row3 col0" >0.0365519</td>
#             </tr>
#             <tr>
#                         <th id="T_39d6519e_7906_11ea_9646_90324b2c20c6level0_row4" class="row_heading level0 row4" >lon</th>
#                         <td id="T_39d6519e_7906_11ea_9646_90324b2c20c6row4_col0" class="data row4 col0" >0.00225896</td>
#             </tr>
#             <tr>
#                         <th id="T_39d6519e_7906_11ea_9646_90324b2c20c6level0_row5" class="row_heading level0 row5" >lat</th>
#                         <td id="T_39d6519e_7906_11ea_9646_90324b2c20c6row5_col0" class="data row5 col0" >-0.0022588</td>
#             </tr>
#             <tr>
#                         <th id="T_39d6519e_7906_11ea_9646_90324b2c20c6level0_row6" class="row_heading level0 row6" >id_sec</th>
#                         <td id="T_39d6519e_7906_11ea_9646_90324b2c20c6row6_col0" class="data row6 col0" >-0.0159752</td>
#             </tr>
#             <tr>
#                         <th id="T_39d6519e_7906_11ea_9646_90324b2c20c6level0_row7" class="row_heading level0 row7" >id_subsec</th>
#                         <td id="T_39d6519e_7906_11ea_9646_90324b2c20c6row7_col0" class="data row7 col0" >-0.0462282</td>
#             </tr>
#     </tbody></table>

# %%
# Scatter plot:

sns.set()
cols = ['franchise', 'id','in_hex','lon','lat','id_sec','id_subsec']
sns.pairplot(df[cols], size = 2.5)
plt.show();

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ## Tablas de frecuencia

# %%
# tabla de frecuencia de categoria sectores
pd.value_counts(df['cod_sec'])
# Out:
# serv      19296
# localb    13872
# host      12066
# pers       8266
# quot       8220
# other      6051
# llar       3578
# altr       3551
# tran       2800
# cult       2632
# Name: cod_sec, dtype: int64

# %%
# tabla de frecuencia de categoria sectores
100 * df['cod_sec'].value_counts() / len(df['cod_sec'])
# Out:
# serv      24.020316
# localb    17.268336
# host      15.020166
# pers      10.289797
# quot      10.232535
# other      7.532490
# llar       4.454016
# altr       4.420405
# tran       3.485535
# cult       3.276403
# Name: cod_sec, dtype: float64

# %%
# Gráfico de barras de pasajeros del Titanic
plot = df['cod_sec'].value_counts().plot(kind='bar',
                                            title='Sectores comerciales BCN')

# %%
# gráfico de barras de frecuencias relativas.
plot = (100 * df['cod_sec'].value_counts() / len(df['cod_sec'])).plot(
kind='bar', title='Sectores comerciales BCN %')

# %%
# Gráfico de tarta de pasajeros del Titanic
plot = df['cod_sec'].value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(6, 6),
                                            title='Sectores comerciales BCN')

# %% [markdown]
# ## Tablas de contingencia

# %%
pd.crosstab(index=df['franchise'],
            columns=df['cod_sec'], margins=True)
# Out:
# cod_sec    altr  cult   host  llar  localb  other  pers  quot   serv  tran  \
# franchise
# 0.0        3542  2588  11812  3525   13871   6044  7397  7512  18900  2798
# 1.0           9    44    254    53       1      7   869   708    396     2
# All        3551  2632  12066  3578   13872   6051  8266  8220  19296  2800
#
# cod_sec      All
# franchise
# 0.0        77989
# 1.0         2343
# All        80332

# %%
# tabla de contingencia en porcentajes relativos total
pd.crosstab(index=df['franchise'], columns=df['cod_sec'],
            margins=True).apply(lambda r: r/len(df) *100,
                                axis=1)
# Out:
# cod_sec        altr      cult       host      llar     localb     other  \
# franchise
# 0.0        4.409202  3.221630  14.703978  4.388040  17.267092  7.523776
# 1.0        0.011204  0.054773   0.316188  0.065976   0.001245  0.008714
# All        4.420405  3.276403  15.020166  4.454016  17.268336  7.532490
#
# cod_sec         pers       quot       serv      tran         All
# franchise
# 0.0         9.208037   9.351193  23.527361  3.483045   97.083354
# 1.0         1.081761   0.881342   0.492954  0.002490    2.916646
# All        10.289797  10.232535  24.020316  3.485535  100.000000

# %%
# tabla de contingencia en porcentajes relativos segun franquicia
pd.crosstab(index=df['franchise'], columns=df['cod_sec']
           ).apply(lambda r: r/r.sum() *100,
                                axis=1)
# Out:
# cod_sec        altr      cult       host      llar     localb     other  \
# franchise
# 0.0        4.541666  3.318417  15.145726  4.519868  17.785842  7.749811
# 1.0        0.384123  1.877934  10.840802  2.262057   0.042680  0.298762
#
# cod_sec         pers       quot       serv      tran
# franchise
# 0.0         9.484671   9.632128  24.234187  3.587685
# 1.0        37.089202  30.217670  16.901408  0.085361

# %%
# tabla de contingencia en porcentajes relativos segun sector
pd.crosstab(index=df['franchise'], columns=df['cod_sec']
           ).apply(lambda r: r/r.sum() *100,
                                axis=0)
# Out:
# cod_sec        altr       cult       host       llar     localb      other  \
# franchise
# 0.0        99.74655  98.328267  97.894911  98.518726  99.992791  99.884317
# 1.0         0.25345   1.671733   2.105089   1.481274   0.007209   0.115683
#
# cod_sec         pers       quot       serv       tran
# franchise
# 0.0        89.487055  91.386861  97.947761  99.928571
# 1.0        10.512945   8.613139   2.052239   0.071429

# %%
# Gráfico de barras de franquicia segun sector
plot = pd.crosstab(index=df['cod_sec'],
            columns=df['franchise']).apply(lambda r: r/r.sum() *100,
                                              axis=1).plot(kind='bar')

# %%
# Gráfico de barras de sobreviviviente segun clase
plot = pd.crosstab(index=df['franchise'],
            columns=df['cod_sec']
                  ).apply(lambda r: r/r.sum() *100,
                          axis=0).plot(kind='bar', stacked=True)

# %%
df.shape
# Out:
# (80332, 14)

# %%
pd.crosstab(index=df['franchise'],
            columns=df['in_poly'], margins=True)
# Out:
# in_poly        0      1    All
# franchise
# 0.0        55762  22227  77989
# 1.0         1214   1129   2343
# All        56976  23356  80332

# %% [markdown]
# # Análisis Cuantitivativo

# %% [raw]
# df_poly.sort_values(['in_hex'],ascending=False).groupby('in_hex').apply(lambda x: x.reset_index(drop = True))

# %% [raw]
# import googlemaps
# gmaps = googlemaps.Client(key='AIzaSyArrO1AyHkV3GW6l-4-vZAqLunekp83fWc')
